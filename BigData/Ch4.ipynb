# %%
# 판다스 라이브러리 불러오기
import pandas as pd

# 파일 경로를 찾고 변수 file_path에 저장
file_path = 'bicycle.csv'

# read csv() 함수로 데이터 프레임 변환
df1 = pd.read_csv(file_path, engine='python', encoding='euc-kr')

# 데이터프레임 출력
df1
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
# 판다스 라이브러리 불러오기
import pandas as pd

# 파일 경로를 찾고 변수 file_path에 저장
file_path = 'bicycle.xlsx'

# read excel() 함수로 데이터 프레임 변환
df2 = pd.read_excel(file_path)

# 데이터프레임 출력
df2
# Out:
#          자전거번호                대여일시  대여 대여소번호            대여 대여소명  대여거치대  \
# 0    SPB-23220 2019-11-01 08:48:31       646  장한평역 1번출구 (국민은행앞)      3
# 1    SPB-16216 2019-11-04 08:38:39       646  장한평역 1번출구 (국민은행앞)      2
# 2    SPB-21097 2019-11-04 08:46:37       646  장한평역 1번출구 (국민은행앞)      1
# 3    SPB-22292 2019-11-05 08:34:59       646  장한평역 1번출구 (국민은행앞)      1
# 4    SPB-07935 2019-11-05 12:29:00       512        뚝섬역 1번 출구 옆     11
# ..         ...                 ...       ...                ...    ...
# 415  SPB-12116 2019-11-15 04:22:13       112            극동방송국 앞      5
# 416  SPB-17768 2019-11-15 09:31:48       103         망원역 2번출구 앞     14
# 417  SPB-18841 2019-11-15 20:40:40       113       홍대입구역 2번출구 앞     24
# 418  SPB-24467 2019-11-15 21:55:13       152         마포구민체육센터 앞     18
# 419  SPB-17570 2019-11-15 22:16:08       391              정동길입구      7
#
#                    반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간  이용거리
# ...

# %%
# 판다스 라이브러리 불러오기
import pandas as pd

# 파일 경로를 찾고 변수 file_path에 저장
file_path = 'read.json'

# read json() 함수로 데이터 프레임 변환
df3 = pd.read_json(file_path)

# 데이터프레임 출력
df3
# Out:
#   1.FirstName 2.LastName  3.Age       4.University  \
# 0     Gildong       Hong     20  Gachon University
# 1     Gildong       Hong     20  Gachon University
#
#                                            5.Courses
# 0  {'Classes': ['Probability', 'Generalized Linea...
# 1  {'Classes': ['Data Structure', 'Programming', ...

# %%
# 판다스 라이브러리 불러오기
import pandas as pd

# 파일 경로를 찾고 변수 file_path에 저장
file_path = 'bicycle.csv'

# read csv() 함수로 데이터 프레임 변환
df1 = pd.read_csv(file_path, engine='python', encoding='euc-kr')

# to csv() 함수로 csv 파일로 내보내기
df1.to_csv('bicycle_b.csv')

# 저장 파일 확인
file_path = 'bicycle_b.csv'
df4 = pd.read_csv(file_path, engine='python')
df4
# Out:
#      Unnamed: 0      자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0             0  SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1             1  SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2             2  SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3             3  SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4             4  SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..          ...        ...               ...    ...                ...    ...
# 415         415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416         416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417         417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418         418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419         419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
# ...

# %%
# 판다스 라이브러리 불러오기
import pandas as pd

# 파일 경로를 찾고 변수 file_path에 저장
file_path = 'bicycle.xlsx'

# read excel() 함수로 데이터 프레임 변환
df2 = pd.read_excel(file_path)

# to excel() 함수로 xlsx 파일로 내보내기
df2.to_excel('bicycle_b.xlsx')

# 저장 파일 확인
file_path = 'bicycle_b.xlsx'
df5 = pd.read_excel(file_path)
df5
# Out:
#      Unnamed: 0      자전거번호                대여일시  대여 대여소번호            대여 대여소명  \
# 0             0  SPB-23220 2019-11-01 08:48:31       646  장한평역 1번출구 (국민은행앞)
# 1             1  SPB-16216 2019-11-04 08:38:39       646  장한평역 1번출구 (국민은행앞)
# 2             2  SPB-21097 2019-11-04 08:46:37       646  장한평역 1번출구 (국민은행앞)
# 3             3  SPB-22292 2019-11-05 08:34:59       646  장한평역 1번출구 (국민은행앞)
# 4             4  SPB-07935 2019-11-05 12:29:00       512        뚝섬역 1번 출구 옆
# ..          ...        ...                 ...       ...                ...
# 415         415  SPB-12116 2019-11-15 04:22:13       112            극동방송국 앞
# 416         416  SPB-17768 2019-11-15 09:31:48       103         망원역 2번출구 앞
# 417         417  SPB-18841 2019-11-15 20:40:40       113       홍대입구역 2번출구 앞
# 418         418  SPB-24467 2019-11-15 21:55:13       152         마포구민체육센터 앞
# 419         419  SPB-17570 2019-11-15 22:16:08       391              정동길입구
#
# ...

# %%
# 판다스 라이브러리 불러오기
import pandas as pd

# 파일 경로를 찾고 변수 file_path에 저장
file_path = 'read.json'

# read json() 함수로 데이터 프레임 변환
df3 = pd.read_json(file_path)

# to json() 함수로 json 파일로 내보내기
df3.to_json('read_b.json')

# 저장 파일 확인
file_path = 'read_b.json'
df6 = pd.read_json(file_path)
df6
# Out:
#   1.FirstName 2.LastName  3.Age       4.University  \
# 0     Gildong       Hong     20  Gachon University
# 1     Gildong       Hong     20  Gachon University
#
#                                            5.Courses
# 0  {'Classes': ['Probability', 'Generalized Linea...
# 1  {'Classes': ['Data Structure', 'Programming', ...
